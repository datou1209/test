# %% [markdown]
# <a href="https://colab.research.google.com/github/datou1209/test/blob/main/yolov5_obb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Mar  8 08:53:35 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    28W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/hukaixuan19970627/yolov5_obb.git
# Out:
# Cloning into 'yolov5_obb'...
# remote: Enumerating objects: 704, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 704 (delta 153), reused 85 (delta 85), pack-reused 506
# Receiving objects: 100% (704/704), 18.16 MiB | 22.30 MiB/s, done.
# Resolving deltas: 100% (321/321), done.

# %%
# %cd yolov5_obb/
# Out:
# /content/yolov5_obb

# %%
# !python detect.py
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory

# %%
# %cd /content/yolov5_obb/utils/nms_rotated
# Out:
# /content/yolov5_obb/utils/nms_rotated

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating nms_rotated.egg-info
# writing nms_rotated.egg-info/PKG-INFO
# writing dependency_links to nms_rotated.egg-info/dependency_links.txt
# writing top-level names to nms_rotated.egg-info/top_level.txt
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'nms_rotated.egg-info/SOURCES.txt'
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# running build_ext
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:387: UserWarning: The detected CUDA version (11.8) has a minor version mismatch with the version that was used to compile PyTorch (11.6). Most likely this shouldn't be a problem.
# ...

# %%
# %cd yolov5_obb/
# Out:
# [Errno 2] No such file or directory: 'yolov5_obb/'
# /content/yolov5_obb

# %%
# %cd /content/yolov5_obb/
# Out:
# /content/yolov5_obb

# %%
# !sed -i '1,2d' /content/yolov5_obb/dataset/dataset_demo/labelTxt/*.txt

# %%
# !python /content/yolov5_obb/train.py
# Out:
# train: weights=weights/yolov5n.pt, cfg=, data=data/yolov5obb_demo.yaml, hyp=data/hyps/obb/hyp.finetune_dota.yaml, epochs=10, batch_size=1, imgsz=840, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/hukaixuan19970627/yolov5_obb ✅
# YOLOv5 🚀 b00c3f2 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# %cd /content/yolov5_obb/utils/nms_rotated/src
# Out:
# /content/yolov5_obb/utils/nms_rotated/src

# %%
# %cd /content/yolov5_obb/utils/nms_rotated
# Out:
# /content/yolov5_obb/utils/nms_rotated

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating nms_rotated.egg-info
# writing nms_rotated.egg-info/PKG-INFO
# writing dependency_links to nms_rotated.egg-info/dependency_links.txt
# writing top-level names to nms_rotated.egg-info/top_level.txt
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'nms_rotated.egg-info/SOURCES.txt'
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# running build_ext
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:782: UserWarning: The detected CUDA version (11.8) has a minor version mismatch with the version that was used to compile PyTorch (11.1). Most likely this shouldn't be a problem.
# ...

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating nms_rotated.egg-info
# writing nms_rotated.egg-info/PKG-INFO
# writing dependency_links to nms_rotated.egg-info/dependency_links.txt
# writing top-level names to nms_rotated.egg-info/top_level.txt
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:381: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'nms_rotated.egg-info/SOURCES.txt'
# writing manifest file 'nms_rotated.egg-info/SOURCES.txt'
# running build_ext
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:782: UserWarning: The detected CUDA version (11.8) has a minor version mismatch with the version that was used to compile PyTorch (11.1). Most likely this shouldn't be a problem.
# ...

# %%
# !pip install torch==1.10.0+cu111 torchvision==0.11.0+cu111 torchaudio==0.10.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 GB 824.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 66.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 52.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ...

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# ...
#   Using cached https://download.pytorch.org/whl/cu116/torch-1.13.1%2Bcu116-cp38-cp38-linux_x86_64.whl (1977.9 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu116/torchvision-0.14.1%2Bcu116-cp38-cp38-linux_x86_64.whl (24.2 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu116/torchaudio-0.13.1%2Bcu116-cp38-cp38-linux_x86_64.whl (4.2 MB)
# ...

# %%
# !python detect.py
# Out:
# Traceback (most recent call last):
#   File "detect.py", line 30, in <module>
#     from models.common import DetectMultiBackend
#   File "/content/yolov5_obb/models/common.py", line 23, in <module>
#     from utils.datasets import exif_transpose, letterbox
#   File "/content/yolov5_obb/utils/datasets.py", line 28, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
#   File "/content/yolov5_obb/utils/augmentations.py", line 12, in <module>
#     from utils.general import LOGGER, check_version, colorstr, resample_segments, segment2box
#   File "/content/yolov5_obb/utils/general.py", line 35, in <module>
#     from utils.nms_rotated import obb_nms
#   File "/content/yolov5_obb/utils/nms_rotated/__init__.py", line 1, in <module>
#     from .nms_rotated_wrapper import obb_nms, poly_nms
#   File "/content/yolov5_obb/utils/nms_rotated/nms_rotated_wrapper.py", line 4, in <module>
# ...

# %%
# !rm -rf /content/yolov5_obb/dataset/dataset_demo/train

# %%
# !cp -r /content/yolov5_obb/dataset/dataset_demo/train/images /content/yolov5_obb/dataset/dataset_demo

# %%
# !cp /content/drive/MyDrive/train.rar /content/yolov5_obb/dataset/dataset_demo

# %%
# !cd /content/yolov5_obb/DOTA_devkit

# %%
# !python /content/yolov5_obb/train.py
# Out:
# train: weights=weights/yolov5n.pt, cfg=, data=data/yolov5obb_demo.yaml, hyp=data/hyps/obb/hyp.finetune_dota.yaml, epochs=10, batch_size=1, imgsz=840, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/hukaixuan19970627/yolov5_obb ✅
# YOLOv5 🚀 b00c3f2 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python /content/yolov5_obb/DOTA_devkit/dota_poly2rbox.py --path '/content/yolov5_obb/dataset/dataset_demo'
# Out:
# P0000.png
# Traceback (most recent call last):
#   File "/content/yolov5_obb/DOTA_devkit/dota_poly2rbox.py", line 250, in <module>
#     convert2rbox(args.path)
#   File "/content/yolov5_obb/DOTA_devkit/dota_poly2rbox.py", line 234, in convert2rbox
#     bbox = [np.float32(ann_line[i]) for i in range(8)]
#   File "/content/yolov5_obb/DOTA_devkit/dota_poly2rbox.py", line 234, in <listcomp>
#     bbox = [np.float32(ann_line[i]) for i in range(8)]
# ValueError: could not convert string to float: 'imagesource:GoogleEarth'

# %%
# !unrar x /content/yolov5_obb/dataset/dataset_demo/labelTxt.rar /content/yolov5_obb/dataset/dataset_demo
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/yolov5_obb/dataset/dataset_demo/labelTxt.rar
#
# Creating    /content/yolov5_obb/dataset/dataset_demo/labelTxt         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...
